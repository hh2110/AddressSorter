# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gmplot import gmplot
import googlemaps
import random
import folium
from folium.plugins import HeatMap
import os

# %%
# read in csv as df (with the first column as index_col)
data = pd.read_csv("./data/Jan19_SH.csv", index_col=0)

# remove unwanted columns
unwanted=['opdhVbp', 'vstId', 'vstDate', 'opdhVpulse',
          'opdhVtemp', 'opdhDhtn', 'opdhDihd', 'opdhDhyper',
          'pntAge', 'opdhVbmi', 'opdhVheight', 'opdhVweight',
          'opdhDdm', 'vstAmount', 'vsrcId']
data.drop(unwanted, inplace=True, axis=1)
# inplace=true tells pd to make the changes in our object
# axis=1 - dropping columns

# check for empty cells and replace with 'Pakistan' (default)
print('number of empty cells', data.isnull().sum())
data['pntAddress']=data['pntAddress'].fillna('Pakistan')
print('number of empty cells after fillna', data.isnull().sum(), '\n')

# check the types of data in the addresses column
print('type of data in the df ', data.dtypes)
print('shape of dataFrame ', np.shape(data), '\n')

# %%
# need to use googlemaps to find lat and loong of addresses
with open('api.txt') as f:
    myAPIkey=f.readline()
# set the api key first
gmaps_key=googlemaps.Client(key = myAPIkey)

# create empty Lon and Lat columns ... and google maps name
# geocode_object should be included too 
data["LAT"] = None
data["LON"] = None
data["GMAPS_NAME"] = None
data["GEOCODE_OBJECT"] = None
data["PARTIAL_RESULT"] = None

# find lat, lon for a random 50 addresses and add them to the dataFrame
chosen=random.sample(range(0, len(data)), 50)
for i in chosen:
    geocode_result = gmaps_key.geocode(data['pntAddress'][i]+', Pakistan')
    try:
        lat = geocode_result[0]["geometry"]["location"]["lat"]
        lon = geocode_result[0]["geometry"]["location"]["lng"]
        gname = geocode_result[0]["formatted_address"]
        gdata = geocode_result[0]
#         partial = checkPartialMatch(geocode_result)
        data.iat[i, data.columns.get_loc("LAT")] = lat
        data.iat[i, data.columns.get_loc("LON")] = lon
        data.iat[i, data.columns.get_loc("GMAPS_NAME")] = gname
        data.iat[i, data.columns.get_loc("GEOCODE_OBJECT")] = gdata
#         data.iat[i, data.columns.get_loc("PARTIAL_RESULT")] = partial
    except:
        gname = None
        lat = None 
        lon = None
        print("couldn't find address", i, data['pntAddress'][i])

# isloate the lon and lat data
latList=data["LAT"].values;
lonList=data["LON"].values;

# remove any None values for where lon and lat data could not be found
# or where address was not searched for
latList=latList[latList != np.array(None)]
lonList=lonList[lonList != np.array(None)]

# %%
import csv
with open(r'./data/PtData.csv','r') as f:
    reader = csv.reader(f)
    linenumber = 1
    try:
        for row in reader:
            linenumber += 1
    except Exception as e:
        print (("Error line %d: %s %s" % (linenumber, str(type(e)), e.message)))

# %%
data=pd.read_csv('./data/PtData.csv', index_col=0)

# %%
data['pntAddress'].str.contains('\r', regex=False).sum()

# %%
# remove unwanted columns
# unwanted=['opdhVbp', 'vstId', 'vstDate', 'opdhVpulse',
#           'opdhVtemp', 'opdhDhtn', 'opdhDihd', 'opdhDhyper',
#           'pntAge', 'opdhVbmi', 'opdhVheight', 'opdhVweight',
#           'opdhDdm', 'vstAmount', 'vsrcId']
# data.drop(unwanted, inplace=True, axis=1)
# inplace=true tells pd to make the changes in our object
# axis=1 - dropping columns

data = data.replace(r'\r','', regex=True) 

# check for empty cells and replace with 'Pakistan' (default)
print('number of empty cells', data.isnull().sum())
data['pntAddress']=data['pntAddress'].fillna('Pakistan')
print('number of empty cells after fillna', data.isnull().sum(), '\n')

# check the types of data in the addresses column
print('type of data in the df ', data.dtypes)
print('shape of dataFrame ', np.shape(data), '\n')

# %%
data.to_csv('./data/CleanPtData.csv')

# %%
# create dataframe
data = pd.read_csv('../data/GMapsAddress_1329.csv', index_col=0)
# isloate the lon and lat data
latList=data["LAT"].values;
lonList=data["LON"].values;


print(np.isnan(latList).sum())
# Out:
# 132

# %%
data.dtypes
data.sample(50)
# Out:
#        pntAge pntGender                                  pntAddress  \
# index
# 10057    24.0         F                                    peshawar
# 14822    35.0         F                          Bara Gate,Peshawar
# 10777    65.0         M                             peshawar saddar
# 5076     48.0         M                                   hayatabad
# 5219      0.0         M                                   HAYATABAD
# 10119    57.0         M                                         dir
# 3101     60.0         F                        Sufaid Deri Peshawar
# 14404    62.0         M                  Parachinar (Naeem Khattak)
# 12404    50.0         M                          malakand dargi kpk
# 8214     55.0         F                                       karak
# 3298     50.0         F                               Shaheen bazar
# 13299    65.0         M                                  DOLAT PURA
# 7315     50.0         F                                    Peshawar
# 9026     42.0         F                   khazno mill charsada road
# 5436     45.0         F                                   shabqadar
# 12493    31.0         M                                    chamkani
# 14987    67.0         M                   Phase1 hayatabad,Peshawar
# 3434     63.0         M         Lalazar colony peshawa5r university
# 3030     42.0         F                        Sufaid Deri Peshawar
# 6946     50.0         M                  Phase 1 Aayatabad Peshawar
# 13631    38.0         M                         Rahat Abad Peshawar
# 883      48.0         F                         Der colony peshawar
# 9641     50.0         M                              bajawar agency
# 11458    82.0         M                                   hayatabad
# 4295     42.0         M                          faqerabab peshawar
# 14862    45.0         M                                    Peshawar
# 13058    20.0         F                                   hayatabad
# 10264    55.0         M                                    peshawar
# 9685     29.0         F                                   shabqadar
# 2195     55.0         M                                      Dargai
# 1997     50.0         M                     Labour Colony Peshawar
# 6595     55.0         F                      Phase 6 Hayatabad Pesh
# 3034     40.0         F                         aslam deri Peshawar
# 13432    40.0         F                               town peshawar
# 11607    55.0         F                                       swabi
# 6406     55.0         F                             Malakand Dargai
# 14938     0.0         F                                Nowshera,kpk
# 4789     25.0         F                   PHASE 1 HAYTABAD PESHAWAR
# 399      30.0         F                      Labour Colony Peshawar
# 523      60.0         F                            Phase 1 Peshawar
# 14650    45.0         M                  hayatabad phase 1,peshawar
# 12243    45.0         F  dir colony rehman baba kohat road peshawar
# 9620     48.0         F                               labour colony
# 6219     38.0         M                                      Sadder
# 10544    55.0         F                          hayatabad peshawar
# 11267    78.0         F                                    peshawar
# 6411     83.0         M                                       Swabi
# 3019     18.0         F                      Labour Colony Peshawar
# 10394    40.0         F                                    peshawar
# 5708     50.0         F                         Bala marai peshawar
#
#              pntRegDate        LAT        LON  \
# index
# 10057  05/01/2018 15:03  34.015137  71.524915
# 14822  11/12/2018 10:54  33.982726  71.524778
# 10777  26/02/2018 12:58  34.009578  71.560925
# 5076   03/12/2016 12:18  33.974411  71.435873
# 5219   16/12/2016 09:39  33.974411  71.435873
# 10119  10/01/2018 12:11  35.197660  71.874921
# 3101   23/05/2016 09:59  33.975103  71.492269
# 14404  07/11/2018 12:21  33.901124  70.086041
# 12404  20/06/2018 10:47  34.507495  71.898636
# 8214   27/07/2017 09:32  33.110479  71.091375
# 3298   04/06/2016 11:56  34.009923  71.577416
# 13299  30/08/2018 10:48  34.172206  71.662886
# 7315   06/05/2017 11:17  34.015137  71.524915
# 9026   03/10/2017 08:36  34.074000  71.594323
# 5436   31/12/2016 09:53  34.218576  71.554591
# 12493  25/06/2018 16:41  34.005893  71.648053
# 14987  24/12/2018 13:01  33.976639  71.432905
# 3434   27/06/2016 09:13  34.020604  71.481272
# 3030   17/05/2016 10:07  33.975103  71.492269
# 6946   12/04/2017 08:43  33.976639  71.432905
# 13631  19/09/2018 09:37  34.021486  71.487817
# 883    26/11/2015 09:37  34.015137  71.524915
# 9641   27/11/2017 14:28  34.786528  71.524915
# 11458  07/04/2018 16:27  33.974411  71.435873
# 4295   01/10/2016 15:48  34.019494  71.583523
# 14862  14/12/2018 09:59  34.015137  71.524915
# 13058  08/08/2018 11:45  33.974411  71.435873
# 10264  22/01/2018 09:32  34.015137  71.524915
# 9685   02/12/2017 12:33  34.218576  71.554591
# 2195   29/03/2016 12:04  34.179815  71.888261
# 1997   17/03/2016 10:23  34.170080  72.032742
# 6595   21/03/2017 11:56  33.955116  71.432905
# 3034   17/05/2016 10:56  34.015137  71.524915
# 13432  06/09/2018 10:43  34.015137  71.524915
# 11607  16/04/2018 10:25  34.124071  72.461319
# 6406   09/03/2017 10:44  34.507495  71.898636
# 14938  20/12/2018 10:03  34.010464  71.987553
# 4789   10/11/2016 09:36  33.976639  71.432905
# 399    14/09/2015 09:52  34.170080  72.032742
# 523    02/10/2015 09:38  33.976639  71.432905
# 14650  28/11/2018 08:42  33.976639  71.432905
# 12243  23/05/2018 11:06  33.914186  71.557567
# 9620   27/11/2017 09:08  24.859509  67.010389
# 6219   27/02/2017 09:02  24.853185  67.016672
# 10544  09/02/2018 09:56  33.974411  71.435873
# 11267  26/03/2018 12:03  34.015137  71.524915
# 6411   09/03/2017 14:42  34.124071  72.461319
# 3019   16/05/2016 12:14  34.170080  72.032742
# 10394  29/01/2018 14:05  34.015137  71.524915
# 5708   23/01/2017 09:38  34.015137  71.524915
#
#                                               GMAPS_NAME  \
# index
# 10057             Peshawar, Khyber Pakhtunkhwa, Pakistan
# 14822  2 Bara Road., Umeedabad, Peshawar, Khyber Pakh...
# 10777  Saddar Rd, Finance Department, Civil Secretari...
# 5076   Hayatabad, Peshawar, Khyber Pakhtunkhwa, Pakistan
# 5219   Hayatabad, Peshawar, Khyber Pakhtunkhwa, Pakistan
# 10119                  Dir, Khyber Pakhtunkhwa, Pakistan
# 3101   Sufaid Dheri, Peshawar, Khyber Pakhtunkhwa, Pa...
# 14404  Parachinar, Kurram Agency, Federally Administe...
# 12404     Dargai, Malakand, Khyber Pakhtunkhwa, Pakistan
# 8214                 Karak, Khyber Pakhtunkhwa, Pakistan
# 3298   Shaheen Bazaar, Peshawar, Khyber Pakhtunkhwa, ...
# 13299  Daulat Pura, Charsadda, Khyber Pakhtunkhwa, Pa...
# 7315              Peshawar, Khyber Pakhtunkhwa, Pakistan
# 9026   Charsadda Rd & Khazana Sugar Mill Rd, Haryana ...
# 5436   Shabqadar, Charsadda, Khyber Pakhtunkhwa, Paki...
# 12493   Chamkani, Peshawar, Khyber Pakhtunkhwa, Pakistan
# 14987  Phase 1 Hayatabad, Peshawar, Khyber Pakhtunkhw...
# 3434   Professors Colony, Peshawar, Khyber Pakhtunkhw...
# 3030   Sufaid Dheri, Peshawar, Khyber Pakhtunkhwa, Pa...
# 6946   Phase 1 Hayatabad, Peshawar, Khyber Pakhtunkhw...
# 13631  Rahat Abad, Peshawar, Khyber Pakhtunkhwa, Paki...
# 883               Peshawar, Khyber Pakhtunkhwa, Pakistan
# 9641   Bajaur Agency, Federally Administered Tribal A...
# 11458  Hayatabad, Peshawar, Khyber Pakhtunkhwa, Pakistan
# 4295   Faqeerabad Zaryab Colony, Peshawar, Khyber Pak...
# 14862             Peshawar, Khyber Pakhtunkhwa, Pakistan
# 13058  Hayatabad, Peshawar, Khyber Pakhtunkhwa, Pakistan
# 10264             Peshawar, Khyber Pakhtunkhwa, Pakistan
# 9685   Shabqadar, Charsadda, Khyber Pakhtunkhwa, Paki...
# 2195     Dargai, Charsadda, Khyber Pakhtunkhwa, Pakistan
# 1997   Labour colony Mardan, Khyber Pakhtunkhwa 23200...
# 6595   Phase 6 Hayatabad, Peshawar, Khyber Pakhtunkhw...
# 3034              Peshawar, Khyber Pakhtunkhwa, Pakistan
# 13432             Peshawar, Khyber Pakhtunkhwa, Pakistan
# 11607                Swabi, Khyber Pakhtunkhwa, Pakistan
# 6406      Dargai, Malakand, Khyber Pakhtunkhwa, Pakistan
# 14938             Nowshera, Khyber Pakhtunkhwa, Pakistan
# 4789   Phase 1 Hayatabad, Peshawar, Khyber Pakhtunkhw...
# 399    Labour colony Mardan, Khyber Pakhtunkhwa 23200...
# 523    Phase 1 Hayatabad, Peshawar, Khyber Pakhtunkhw...
# 14650  Phase 1 Hayatabad, Peshawar, Khyber Pakhtunkhw...
# 12243   Kohat Rd, Peshawar, Khyber Pakhtunkhwa, Pakistan
# 9620   New Labour Colony Karachi, Karachi City, Sindh...
# 6219               Saddar Town, Karachi, Sindh, Pakistan
# 10544  Hayatabad, Peshawar, Khyber Pakhtunkhwa, Pakistan
# 11267             Peshawar, Khyber Pakhtunkhwa, Pakistan
# 6411                 Swabi, Khyber Pakhtunkhwa, Pakistan
# 3019   Labour colony Mardan, Khyber Pakhtunkhwa 23200...
# 10394             Peshawar, Khyber Pakhtunkhwa, Pakistan
# 5708              Peshawar, Khyber Pakhtunkhwa, Pakistan
#
#                                           GEOCODE_OBJECT PARTIAL_RESULT
# index
# 10057  {'address_components': [{'long_name': 'Peshawa...            NaN
# 14822  {'address_components': [{'long_name': '2', 'sh...            NaN
# 10777  {'address_components': [{'long_name': 'Saddar ...            NaN
# 5076   {'address_components': [{'long_name': 'Hayatab...            NaN
# 5219   {'address_components': [{'long_name': 'Hayatab...            NaN
# 10119  {'address_components': [{'long_name': 'Dir', '...            NaN
# 3101   {'address_components': [{'long_name': 'Sufaid ...           True
# 14404  {'address_components': [{'long_name': 'Parachi...           True
# 12404  {'address_components': [{'long_name': 'Dargai'...            NaN
# 8214   {'address_components': [{'long_name': 'Karak',...            NaN
# 3298   {'address_components': [{'long_name': 'Shaheen...            NaN
# 13299  {'address_components': [{'long_name': 'Daulat ...           True
# 7315   {'address_components': [{'long_name': 'Peshawa...            NaN
# 9026   {'address_components': [{'long_name': 'Charsad...           True
# 5436   {'address_components': [{'long_name': 'Shabqad...            NaN
# 12493  {'address_components': [{'long_name': 'Chamkan...            NaN
# 14987  {'address_components': [{'long_name': 'Phase 1...            NaN
# 3434   {'address_components': [{'long_name': 'Profess...           True
# 3030   {'address_components': [{'long_name': 'Sufaid ...           True
# 6946   {'address_components': [{'long_name': 'Phase 1...           True
# 13631  {'address_components': [{'long_name': 'Rahat A...            NaN
# 883    {'address_components': [{'long_name': 'Peshawa...           True
# 9641   {'address_components': [{'long_name': 'Bajaur ...            NaN
# 11458  {'address_components': [{'long_name': 'Hayatab...            NaN
# 4295   {'address_components': [{'long_name': 'Faqeera...           True
# 14862  {'address_components': [{'long_name': 'Peshawa...            NaN
# 13058  {'address_components': [{'long_name': 'Hayatab...            NaN
# 10264  {'address_components': [{'long_name': 'Peshawa...            NaN
# 9685   {'address_components': [{'long_name': 'Shabqad...            NaN
# 2195   {'address_components': [{'long_name': 'Dargai'...            NaN
# 1997   {'address_components': [{'long_name': 'Labour ...           True
# 6595   {'address_components': [{'long_name': 'Phase 6...            NaN
# 3034   {'address_components': [{'long_name': 'Peshawa...           True
# 13432  {'address_components': [{'long_name': 'Peshawa...            NaN
# 11607  {'address_components': [{'long_name': 'Swabi',...            NaN
# 6406   {'address_components': [{'long_name': 'Dargai'...            NaN
# 14938  {'address_components': [{'long_name': 'Nowsher...            NaN
# 4789   {'address_components': [{'long_name': 'Phase 1...            NaN
# 399    {'address_components': [{'long_name': 'Labour ...           True
# 523    {'address_components': [{'long_name': 'Phase 1...            NaN
# 14650  {'address_components': [{'long_name': 'Phase 1...            NaN
# 12243  {'address_components': [{'long_name': 'Kohat R...           True
# 9620   {'address_components': [{'long_name': 'New Lab...            NaN
# 6219   {'address_components': [{'long_name': 'Saddar ...           True
# 10544  {'address_components': [{'long_name': 'Hayatab...            NaN
# 11267  {'address_components': [{'long_name': 'Peshawa...            NaN
# 6411   {'address_components': [{'long_name': 'Swabi',...            NaN
# 3019   {'address_components': [{'long_name': 'Labour ...           True
# 10394  {'address_components': [{'long_name': 'Peshawa...            NaN
# 5708   {'address_components': [{'long_name': 'Peshawa...           True

# %%
# remove any None values for where lon and lat data could not be found
# or where address was not searched for
latList=latList[np.isfinite(latList)];
lonList=lonList[np.isfinite(lonList)];

# %%
print(np.isnan(latList).sum())
print(latList)
# Out:
# 0
# [ 33.9220536  34.0151366  34.0151366 ...,  35.2227114  33.93911    32.98648  ]

# %%
counter=0
for i, row in data.iterrows():
    if row['LAT']!=row['LAT']:
        print(row)
        counter+=1
print(counter)
# Out:
# pntAge                                  46
# pntGender                                F
# pntAddress        Baharat Phase 3 Peshawar
# pntRegDate                13/10/2015 10:52
# LAT                                    NaN
# LON                                    NaN
# GMAPS_NAME                             NaN
# GEOCODE_OBJECT                         NaN
# PARTIAL_RESULT                         NaN
# Name: 627, dtype: object
# pntAge                          43
# pntGender                        M
# pntAddress                Phase 5
# pntRegDate        22/10/2015 10:26
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 668, dtype: object
# pntAge                          55
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        26/10/2015 09:25
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 674, dtype: object
# pntAge                          36
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        27/10/2015 08:58
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 677, dtype: object
# pntAge                          75
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        27/10/2015 09:35
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 679, dtype: object
# pntAge                          52
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        06/11/2015 10:08
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 731, dtype: object
# pntAge                          20
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        18/11/2015 11:58
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 818, dtype: object
# pntAge                          43
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        20/11/2015 08:54
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 829, dtype: object
# pntAge                          54
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        24/11/2015 11:09
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 867, dtype: object
# pntAge                          16
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        28/11/2015 11:23
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 895, dtype: object
# pntAge                          52
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        03/12/2015 11:32
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 932, dtype: object
# pntAge                          56
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        04/12/2015 10:51
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 943, dtype: object
# pntAge                          40
# pntGender                        F
# pntAddress                Phase 1
# pntRegDate        11/12/2015 09:22
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1000, dtype: object
# pntAge                          60
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        12/12/2015 11:43
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1016, dtype: object
# pntAge                          65
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        14/12/2015 10:08
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1020, dtype: object
# pntAge                          55
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        15/12/2015 09:41
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1036, dtype: object
# pntAge                          38
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        21/12/2015 10:13
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1073, dtype: object
# pntAge                          65
# pntGender                        F
# pntAddress                Phase 1
# pntRegDate        23/12/2015 10:04
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1089, dtype: object
# pntAge                          64
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        23/12/2015 10:40
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1090, dtype: object
# pntAge                          40
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        23/12/2015 11:42
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1092, dtype: object
# pntAge                          64
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        24/12/2015 14:05
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1099, dtype: object
# pntAge                          36
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        01/01/2016 10:31
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1187, dtype: object
# pntAge                          70
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        01/01/2016 12:38
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1195, dtype: object
# pntAge                          38
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        04/01/2016 11:28
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1209, dtype: object
# pntAge                          44
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        09/01/2016 09:14
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1292, dtype: object
# pntAge                          43
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        09/01/2016 10:21
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1294, dtype: object
# pntAge                          45
# pntGender                        F
# pntAddress                phase 1
# pntRegDate        11/01/2016 09:50
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1308, dtype: object
# pntAge                          48
# pntGender                        M
# pntAddress                phase 1
# pntRegDate        11/01/2016 10:00
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1309, dtype: object
# pntAge                                              43
# pntGender                                            F
# pntAddress        H:25 St: G Phase 5 Haytabad peshawar
# pntRegDate                            14/01/2016 12:12
# LAT                                                NaN
# LON                                                NaN
# GMAPS_NAME                                         NaN
# GEOCODE_OBJECT                                     NaN
# PARTIAL_RESULT                                     NaN
# Name: 1348, dtype: object
# pntAge                                          35
# pntGender                                        F
# pntAddress        Taj Abadv st:18 House:1 Peshawar
# pntRegDate                        18/01/2016 11:47
# LAT                                            NaN
# LON                                            NaN
# GMAPS_NAME                                     NaN
# GEOCODE_OBJECT                                 NaN
# PARTIAL_RESULT                                 NaN
# Name: 1388, dtype: object
# pntAge                          51
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        19/01/2016 09:16
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1389, dtype: object
# pntAge                                                      60
# pntGender                                                    M
# pntAddress        Old labour Colony Phase 5 Haytabad  Peshawar
# pntRegDate                                    20/01/2016 10:56
# LAT                                                        NaN
# LON                                                        NaN
# GMAPS_NAME                                                 NaN
# GEOCODE_OBJECT                                             NaN
# PARTIAL_RESULT                                             NaN
# Name: 1404, dtype: object
# pntAge                                            60
# pntGender                                          F
# pntAddress        st:27 d4 phase 1 haytabad peshawar
# pntRegDate                          20/01/2016 11:56
# LAT                                              NaN
# LON                                              NaN
# GMAPS_NAME                                       NaN
# GEOCODE_OBJECT                                   NaN
# PARTIAL_RESULT                                   NaN
# Name: 1406, dtype: object
# pntAge                          52
# pntGender                        M
# pntAddress                Phase 1
# pntRegDate        27/01/2016 12:04
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 1461, dtype: object
# pntAge                                      61
# pntGender                                    M
# pntAddress        Moh:Allazad Khel Hoti Mardan
# pntRegDate                    23/02/2016 11:30
# LAT                                        NaN
# LON                                        NaN
# GMAPS_NAME                                 NaN
# GEOCODE_OBJECT                             NaN
# PARTIAL_RESULT                             NaN
# Name: 1762, dtype: object
# pntAge                          27
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        28/03/2016 14:51
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 2140, dtype: object
# pntAge                          30
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        11/04/2016 08:43
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 2397, dtype: object
# pntAge                          34
# pntGender                        M
# pntAddress                 PHASE 5
# pntRegDate        16/04/2016 10:10
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 2499, dtype: object
# pntAge                          48
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        09/05/2016 09:22
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 2888, dtype: object
# pntAge                          60
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        12/05/2016 09:59
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 2958, dtype: object
# pntAge                                                          40
# pntGender                                                        F
# pntAddress        Mukarab Khel, Speena Waray,Sufaid Deri Peshawar.
# pntRegDate                                        13/05/2016 09:55
# LAT                                                            NaN
# LON                                                            NaN
# GMAPS_NAME                                                     NaN
# GEOCODE_OBJECT                                                 NaN
# PARTIAL_RESULT                                                 NaN
# Name: 2978, dtype: object
# pntAge                          55
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        30/05/2016 09:19
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3190, dtype: object
# pntAge                          43
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        31/05/2016 09:15
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3204, dtype: object
# pntAge                          63
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        31/05/2016 10:03
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3207, dtype: object
# pntAge                          55
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        02/06/2016 09:08
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3242, dtype: object
# pntAge                          70
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        02/06/2016 09:10
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3243, dtype: object
# pntAge                          34
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        08/06/2016 09:26
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3338, dtype: object
# pntAge                          47
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        15/06/2016 09:11
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3379, dtype: object
# pntAge                          50
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        16/06/2016 11:21
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3386, dtype: object
# pntAge                          45
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        16/06/2016 11:23
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3387, dtype: object
# pntAge                          50
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        16/06/2016 11:54
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3388, dtype: object
# pntAge                          20
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        21/07/2016 10:18
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3586, dtype: object
# pntAge                          23
# pntGender                        F
# pntAddress                 PHASE 5
# pntRegDate        22/07/2016 11:18
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3597, dtype: object
# pntAge                          53
# pntGender                        F
# pntAddress                 PHASE 5
# pntRegDate        22/07/2016 11:21
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3598, dtype: object
# pntAge                                              70
# pntGender                                            F
# pntAddress        Peshawar city hussain abad gulbahar
# pntRegDate                            26/07/2016 14:39
# LAT                                                NaN
# LON                                                NaN
# GMAPS_NAME                                         NaN
# GEOCODE_OBJECT                                     NaN
# PARTIAL_RESULT                                     NaN
# Name: 3644, dtype: object
# pntAge                          52
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        02/08/2016 15:31
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3698, dtype: object
# pntAge                          45
# pntGender                        F
# pntAddress         Shagai peshawar
# pntRegDate        05/08/2016 09:46
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3724, dtype: object
# pntAge                          55
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        06/08/2016 12:32
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3739, dtype: object
# pntAge                          75
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        08/08/2016 12:36
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 3755, dtype: object
# pntAge                          27
# pntGender                        M
# pntAddress                 PHASE 1
# pntRegDate        10/09/2016 11:33
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4098, dtype: object
# pntAge                          38
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        16/09/2016 11:12
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4105, dtype: object
# pntAge                          56
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        19/09/2016 10:17
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4123, dtype: object
# pntAge                           8
# pntGender                        M
# pntAddress                 PHASE 1
# pntRegDate        23/09/2016 11:22
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4186, dtype: object
# pntAge                          30
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        23/09/2016 11:23
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4187, dtype: object
# pntAge                          47
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        26/09/2016 14:46
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4225, dtype: object
# pntAge                          50
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        30/09/2016 14:30
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4277, dtype: object
# pntAge                          60
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        06/10/2016 08:52
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4350, dtype: object
# pntAge                          64
# pntGender                        M
# pntAddress                 PHASE 5
# pntRegDate        21/10/2016 15:04
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4540, dtype: object
# pntAge                          75
# pntGender                        M
# pntAddress                Phase 1
# pntRegDate        28/10/2016 10:00
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4645, dtype: object
# pntAge                          30
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        01/11/2016 12:17
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4690, dtype: object
# pntAge                          50
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        02/11/2016 09:06
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4693, dtype: object
# pntAge                           9
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        05/11/2016 10:56
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4740, dtype: object
# pntAge                          36
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        05/11/2016 10:57
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4741, dtype: object
# pntAge                          73
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        05/11/2016 10:59
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4742, dtype: object
# pntAge                          66
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        08/11/2016 11:15
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4764, dtype: object
# pntAge                          55
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        12/11/2016 08:55
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4824, dtype: object
# pntAge                          65
# pntGender                        F
# pntAddress                phase 1
# pntRegDate        22/11/2016 09:24
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4935, dtype: object
# pntAge                          42
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        26/11/2016 11:31
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 4984, dtype: object
# pntAge                          45
# pntGender                        F
# pntAddress                    CITY
# pntRegDate        28/11/2016 14:10
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5003, dtype: object
# pntAge                          56
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        30/11/2016 10:42
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5022, dtype: object
# pntAge                          48
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        03/12/2016 09:04
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5061, dtype: object
# pntAge                          43
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        03/12/2016 09:05
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5062, dtype: object
# pntAge                          32
# pntGender                        M
# pntAddress                 PHASE 5
# pntRegDate        03/12/2016 10:08
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5066, dtype: object
# pntAge                          50
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        05/12/2016 09:42
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5085, dtype: object
# pntAge                          36
# pntGender                        M
# pntAddress                 PHASE 1
# pntRegDate        05/12/2016 09:57
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5087, dtype: object
# pntAge                          25
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        05/12/2016 09:58
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5088, dtype: object
# pntAge                           6
# pntGender                        M
# pntAddress                 PHASE 5
# pntRegDate        05/12/2016 12:33
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5097, dtype: object
# pntAge                          28
# pntGender                        F
# pntAddress                 PHASE 5
# pntRegDate        05/12/2016 12:34
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5098, dtype: object
# pntAge                          23
# pntGender                        F
# pntAddress                 PHASE 5
# pntRegDate        06/12/2016 10:58
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5109, dtype: object
# pntAge                          26
# pntGender                        M
# pntAddress                 PHASE 5
# pntRegDate        06/12/2016 11:09
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5110, dtype: object
# pntAge                          46
# pntGender                        F
# pntAddress                Phase 1
# pntRegDate        07/12/2016 09:47
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5121, dtype: object
# pntAge                          48
# pntGender                        F
# pntAddress                Phase 1
# pntRegDate        08/12/2016 12:18
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5144, dtype: object
# pntAge                          55
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        14/12/2016 12:49
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5197, dtype: object
# pntAge                          70
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        19/12/2016 10:30
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5255, dtype: object
# pntAge                          75
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        19/12/2016 13:57
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5267, dtype: object
# pntAge                          78
# pntGender                        M
# pntAddress                 PHASE 1
# pntRegDate        20/12/2016 11:38
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5279, dtype: object
# pntAge                          71
# pntGender                        M
# pntAddress                 Phase 1
# pntRegDate        20/12/2016 13:31
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5282, dtype: object
# pntAge                          50
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        24/12/2016 08:37
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5333, dtype: object
# pntAge                          45
# pntGender                        F
# pntAddress                 PHASE 1
# pntRegDate        24/12/2016 12:37
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5346, dtype: object
# pntAge                          10
# pntGender                        M
# pntAddress                    CITY
# pntRegDate        24/12/2016 13:47
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5349, dtype: object
# pntAge                          20
# pntGender                        M
# pntAddress                    town
# pntRegDate        12/01/2017 12:03
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 5608, dtype: object
# pntAge                                            48
# pntGender                                          F
# pntAddress        house 340,st 11 ,phase 6 hayatabad
# pntRegDate                          27/01/2017 08:37
# LAT                                              NaN
# LON                                              NaN
# GMAPS_NAME                                       NaN
# GEOCODE_OBJECT                                   NaN
# PARTIAL_RESULT                                   NaN
# Name: 5753, dtype: object
# pntAge                                                   30
# pntGender                                                 M
# pntAddress        Hayatabad Phase 3 PeshawarBrother (Fahim)
# pntRegDate                                 08/02/2017 08:48
# LAT                                                     NaN
# LON                                                     NaN
# GMAPS_NAME                                              NaN
# GEOCODE_OBJECT                                          NaN
# PARTIAL_RESULT                                          NaN
# Name: 5918, dtype: object
# pntAge                                    0
# pntGender                                 F
# pntAddress        hayatabad Medical complex
# pntRegDate                 09/02/2017 11:42
# LAT                                     NaN
# LON                                     NaN
# GMAPS_NAME                              NaN
# GEOCODE_OBJECT                          NaN
# PARTIAL_RESULT                          NaN
# Name: 5951, dtype: object
# pntAge                                            70
# pntGender                                          F
# pntAddress        Phase 4 Hayatabad Care of Dr Rifat
# pntRegDate                          24/02/2017 12:04
# LAT                                              NaN
# LON                                              NaN
# GMAPS_NAME                                       NaN
# GEOCODE_OBJECT                                   NaN
# PARTIAL_RESULT                                   NaN
# Name: 6202, dtype: object
# pntAge                                            48
# pntGender                                          F
# pntAddress        Phase 4 Hayatabad Care of Dr Rifat
# pntRegDate                          24/02/2017 12:32
# LAT                                              NaN
# LON                                              NaN
# GMAPS_NAME                                       NaN
# GEOCODE_OBJECT                                   NaN
# PARTIAL_RESULT                                   NaN
# Name: 6203, dtype: object
# pntAge                          65
# pntGender                        F
# pntAddress                Phase 1
# pntRegDate        02/03/2017 15:41
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 6301, dtype: object
# pntAge                                              48
# pntGender                                            F
# pntAddress        Phase 1 Hayatabad PeshawarC/Of Fahim
# pntRegDate                            03/03/2017 14:39
# LAT                                                NaN
# LON                                                NaN
# GMAPS_NAME                                         NaN
# GEOCODE_OBJECT                                     NaN
# PARTIAL_RESULT                                     NaN
# Name: 6318, dtype: object
# pntAge                                                           62
# pntGender                                                         M
# pntAddress        Phase 1 D4 h 994 st 38 Hayatabad              ...
# pntRegDate                                         04/03/2017 15:59
# LAT                                                             NaN
# LON                                                             NaN
# GMAPS_NAME                                                      NaN
# GEOCODE_OBJECT                                                  NaN
# PARTIAL_RESULT                                                  NaN
# Name: 6338, dtype: object
# pntAge                          34
# pntGender                        M
# pntAddress                    City
# pntRegDate        20/03/2017 12:20
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 6576, dtype: object
# pntAge                                             60
# pntGender                                           M
# pntAddress        Phase 1 Hayatabad PeshC/O DR Fahkar
# pntRegDate                           28/03/2017 14:00
# LAT                                               NaN
# LON                                               NaN
# GMAPS_NAME                                        NaN
# GEOCODE_OBJECT                                    NaN
# PARTIAL_RESULT                                    NaN
# Name: 6729, dtype: object
# pntAge                             0
# pntGender                          F
# pntAddress        Phase 3 Chock Pesh
# pntRegDate          03/04/2017 10:10
# LAT                              NaN
# LON                              NaN
# GMAPS_NAME                       NaN
# GEOCODE_OBJECT                   NaN
# PARTIAL_RESULT                   NaN
# Name: 6799, dtype: object
# pntAge                          40
# pntGender                        M
# pntAddress                    City
# pntRegDate        03/04/2017 13:31
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 6818, dtype: object
# pntAge                          26
# pntGender                        F
# pntAddress                phase 1
# pntRegDate        12/04/2017 14:06
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 6966, dtype: object
# pntAge                          50
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        25/04/2017 08:23
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 7131, dtype: object
# pntAge                          30
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        25/04/2017 09:03
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 7138, dtype: object
# pntAge                          54
# pntGender                        M
# pntAddress                    city
# pntRegDate        29/04/2017 10:40
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 7202, dtype: object
# pntAge                          45
# pntGender                        M
# pntAddress                    town
# pntRegDate        20/09/2017 10:42
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 8871, dtype: object
# pntAge                          57
# pntGender                        M
# pntAddress                   tall
# pntRegDate        25/09/2017 14:30
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 8952, dtype: object
# pntAge                                                  33
# pntGender                                                M
# pntAddress        labour colomy phase 5 hayatabad peshawar
# pntRegDate                                29/12/2017 12:00
# LAT                                                    NaN
# LON                                                    NaN
# GMAPS_NAME                                             NaN
# GEOCODE_OBJECT                                         NaN
# PARTIAL_RESULT                                         NaN
# Name: 9951, dtype: object
# pntAge                                        56
# pntGender                                      M
# pntAddress        labour colony phase 5 peshawar
# pntRegDate                      30/12/2017 11:29
# LAT                                          NaN
# LON                                          NaN
# GMAPS_NAME                                   NaN
# GEOCODE_OBJECT                               NaN
# PARTIAL_RESULT                               NaN
# Name: 9968, dtype: object
# pntAge                          70
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        15/01/2018 13:14
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 10187, dtype: object
# pntAge                          45
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        02/02/2018 10:02
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 10442, dtype: object
# pntAge                                                  10
# pntGender                                                M
# pntAddress        hayatabad phase 5 labour colony peshawar
# pntRegDate                                12/03/2018 09:46
# LAT                                                    NaN
# LON                                                    NaN
# GMAPS_NAME                                             NaN
# GEOCODE_OBJECT                                         NaN
# PARTIAL_RESULT                                         NaN
# Name: 11024, dtype: object
# pntAge                          27
# pntGender                        F
# pntAddress                 Phase 1
# pntRegDate        15/03/2018 09:27
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 11091, dtype: object
# pntAge                            50
# pntGender                          M
# pntAddress        Gul abad Matra Pkp
# pntRegDate          19/04/2018 11:00
# LAT                              NaN
# LON                              NaN
# GMAPS_NAME                       NaN
# GEOCODE_OBJECT                   NaN
# PARTIAL_RESULT                   NaN
# Name: 11677, dtype: object
# pntAge                          55
# pntGender                        F
# pntAddress                 phase 1
# pntRegDate        16/05/2018 08:25
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 12159, dtype: object
# pntAge                          58
# pntGender                        M
# pntAddress                    town
# pntRegDate        12/06/2018 12:54
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 12368, dtype: object
# pntAge                                   50
# pntGender                                 M
# pntAddress        Board canal town peshawar
# pntRegDate                 25/06/2018 09:06
# LAT                                     NaN
# LON                                     NaN
# GMAPS_NAME                              NaN
# GEOCODE_OBJECT                          NaN
# PARTIAL_RESULT                          NaN
# Name: 12465, dtype: object
# pntAge                          70
# pntGender                        F
# pntAddress                    city
# pntRegDate        08/11/2018 15:58
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 14419, dtype: object
# pntAge                                     45
# pntGender                                   M
# pntAddress        Abdra Shaheen Town peshawar
# pntRegDate                   30/11/2018 10:35
# LAT                                       NaN
# LON                                       NaN
# GMAPS_NAME                                NaN
# GEOCODE_OBJECT                            NaN
# PARTIAL_RESULT                            NaN
# Name: 14678, dtype: object
# pntAge                          40
# pntGender                        M
# pntAddress                 phase 1
# pntRegDate        05/01/2019 08:46
# LAT                            NaN
# LON                            NaN
# GMAPS_NAME                     NaN
# GEOCODE_OBJECT                 NaN
# PARTIAL_RESULT                 NaN
# Name: 15116, dtype: object
# 132

# %%
# use folium to add heat map to map of peshawar 
hmap = folium.Map(location=[33.99, 71.52], zoom_start=12, )
exit()
heat = HeatMap( list(zip(latList, lonList)),
                   min_opacity=0.2,
                   max_val=100,
                   radius=20, blur=15, 
                   max_zoom=10, 
                 )
hmap.add_child(heat)

time=datetime.now().strftime('%H%M')
hmap.save('../data/'+'initial_folium'+time+'.html')
